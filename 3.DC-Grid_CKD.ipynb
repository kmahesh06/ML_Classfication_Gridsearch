# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
dataset=dataset.replace({True: 1,False: 0})
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
indep=dataset[['age', 'bp','al','su','bgr','bu','sc','sod','pot','hrmo','rbc_normal','pc_normal','pcc_present','ba_present','pcv','wc','rc','htn_yes','dm_yes','cad_yes','appet_yes','pe_yes','ane_yes']]
dep=dataset['classification_yes']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['gini','entropy'],
              'max_features': ['auto','sqrt','log2'],
              'splitter':['best','random']} 



grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'gini', 'max_features': 'log2', 'splitter': 'random'}: 0.9624731911379498

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[49  2]
#  [ 3 79]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        51
#            1       0.98      0.96      0.97        82
#
#     accuracy                           0.96       133
#    macro avg       0.96      0.96      0.96       133
# weighted avg       0.96      0.96      0.96       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9620994739359159

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003128      0.006256         0.009625        0.006223
# 1        0.004347      0.005893         0.002749        0.004444
# 2        0.003130      0.006260         0.003130        0.006260
# 3        0.003130      0.006260         0.001116        0.002232
# 4        0.002497      0.004081         0.004392        0.003579
# 5        0.001694      0.002227         0.002797        0.002468
# 6        0.000000      0.000000         0.004466        0.005470
# 7        0.002897      0.004329         0.006397        0.004032
# 8        0.000604      0.000740         0.001673        0.003346
# 9        0.002948      0.002848         0.002544        0.002972
# 10       0.002199      0.001300         0.001810        0.001199
# 11       0.001870      0.001043         0.002552        0.001507
#
#    param_criterion param_max_features param_splitter  \
# 0             gini               auto           best
# ...

# %%
age=float(input("age:"))
bp=float(input("bp:"))
al=float(input("al:"))
su=float(input("su:"))
bgr=float(input("bgr:"))
bu=float(input("bu:"))
sc=float(input("sc:"))
sod=float(input("sod:"))
pot=float(input("pot:"))
hrmo=float(input("hrmo:"))
rbc_normal=int(input("rbc_normal 1 or 0:"))
pc_normal=int(input("pc_normal 1 or 0:"))
pcc_present=int(input("pcc_present 1 or 0:"))
ba_present=int(input("ba_present 1 or 0:"))
pcv=float(input("pcv:"))
wc=float(input("wc:"))
rc=float(input("rc:"))
htn_yes=int(input("htn_yes 1 or 0:"))
dm_yes=int(input("dm_yes 1 or 0:"))
cad_yes=int(input("cad_yes 1 or 0:"))
appet_yes=int(input("appet_yes 1 or 0:"))
pe_yes=int(input("pe_yes 1 or 0:"))
ane_yes=int(input("ane_yes 1 or 0:"))
# Out:
# age: 51.34
# bp: 70.00
# al: 23.00
# su: 23.00
# bgr: 219.00
# bu: 36.00
# sc: 1.3
# sod: 139
# pot: 3.7
# hrmo: 12.5
# rbc_normal 1 or 0: 0
# pc_normal 1 or 0: 0
# pcc_present 1 or 0: 1
# ba_present 1 or 0: 1
# pcv: 37.00
# wc: 9800.00
# rc: 4.4
# htn_yes 1 or 0: 1
# dm_yes 1 or 0: 1
# cad_yes 1 or 0: 0
# appet_yes 1 or 0: 0
# pe_yes 1 or 0: 0
# ane_yes 1 or 0: 1

# %%
Future_Prediction=grid.predict([[age, bp,al,su,bgr,bu,sc,sod,pot,hrmo,rbc_normal,pc_normal,pcc_present,ba_present,pcv,wc,rc,htn_yes,dm_yes,cad_yes,appet_yes,pe_yes,ane_yes]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
